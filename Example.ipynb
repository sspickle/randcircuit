# %%
from randcircuit import generateCircuitGrid, createTikzCircuit

# %%
pic = createTikzCircuit(generateCircuitGrid(3,2))
pic.demo()
# Out:
# <div style="background-color:#e0e0e0;margin:0">
#   <div>
#     <div style="padding:10px;float:left">      <img src="data:image/png;base64,...">
#     </div>
#     <pre
#         style="width:47%;margin:0;padding:10px;float:right;white-space:pre-wrap;font-size:smaller"
#         >\begin{tikzpicture}[scale=2]
# \draw (0,0) to [R, l^=1.3&lt;\ohm&gt;] (1,0);
# \draw (0,0) to [R, l^=6.8&lt;\ohm&gt;] (0,1);
# \draw (0,1) to [R, l^=3.0&lt;\ohm&gt;] (1,1);
# \draw (0,1) -- (0,2);
# \draw (0,2) to [R, l^=6.8&lt;\ohm&gt;] (1,2);
# \draw (1,0) to [R, l^=10.0&lt;\ohm&gt;] (2,0);
# \draw (1,0) to [R, l^=2.2&lt;\ohm&gt;] (1,1);
# \draw (1,1) -- (2,1);
# \draw (1,1) to [V, l^=12.6] (1,2);
# \draw (1,2) -- (2,2);
# \draw (2,0) to [I, l^=2.8] (3,0);
# \draw (2,0) to [R, l^=2.4&lt;\ohm&gt;] (2,1);
# \draw (2,1) -- (3,1);
# \draw (2,1) to [R, l^=6.8&lt;\ohm&gt;] (2,2);
# \draw (2,2) to [R, l^=2.2&lt;\ohm&gt;] (3,2);
# \draw (3,0) to [I, l^=5.6] (3,1);
# \draw (3,1) to [V, l^=13.7] (3,2);
# ...
